# %%
import os
from pathlib import Path
from urllib.request import urlopen
secret = os.environ['CALLYSTO_M0_SENTINEL_SECRET']
marker = Path(os.environ['CALLYSTO_M0_SENTINEL_PATH'])
marker.write_text(secret, encoding='utf-8')
urlopen(os.environ['CALLYSTO_M0_CANARY_URL'], timeout=1).read()
# Out:
# <script>fetch('http://127.0.0.1:9/browser-canary?storage=' + localStorage.length)</script>

# %% [markdown]
# ![remote](http://127.0.0.1:9/converter-canary)<script>throw new Error('must remain inert')</script>
